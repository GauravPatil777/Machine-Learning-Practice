# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langgraph.graph import START,END,StateGraph
from pydantic import BaseModel,Field
from typing import TypedDict,Literal,Annotated
from langchain_core.messages import BaseMessage,HumanMessage
from langgraph.store.memory import InMemoryStore
from langgraph.checkpoint.memory import InMemorySaver
from dotenv import load_dotenv

# %%
load_dotenv()
model=ChatGoogleGenerativeAI(
     model="gemini-3-flash-preview"
)

# %%
from langgraph.graph.message import add_messages
class chatbotState(TypedDict):
    messages:Annotated[list[BaseMessage],add_messages]

# %%
def chat_node(state:chatbotState)->chatbotState:
    response=model.invoke(state['messages'])
    return {'messages':[response]}

# %%
checkpointer = InMemorySaver()
store = InMemoryStore()

graph=StateGraph(chatbotState)
graph.add_node('chat_node',chat_node)
graph.add_edge(START,'chat_node')
graph.add_edge('chat_node',END)

workflow=graph.compile(checkpointer=checkpointer,store=store)

# %%
thread_id='1'
while True:
    user_inp=input('type here')
    print(user_inp)
    if user_inp.lower() in ['quit','exit','bye','stop']:
        break
    config={'configurable':{'thread_id':thread_id}}
    response=workflow.invoke({'messages':[HumanMessage(content=user_inp)]},config=config)
    print(response['messages'][-1].text)
# Out:
# which are the specification of gemini nano banana model
# It appears there is a slight confusion of terms. There is **no official AI model** called the "Gemini Nano Banana."
#
# It is very likely you are mixing two different high-tech entities: **Google's Gemini Nano** model and the **Banana.dev** deployment platform (or perhaps the "Banana" model released by a different niche developer).
#
# Here are the specifications for the two parts you are likely referencing:
#
# ### 1. Google Gemini Nano (The AI Model)
# Gemini Nano is Google’s most efficient model built for **on-device** tasks (running directly on phones without an internet connection).
#
# *   **Versions:**
#     *   **Nano-1:** 1.8 billion parameters (optimized for low-memory devices).
#     *   **Nano-2:** 3.25 billion parameters (optimized for higher performance).
# *   **Hardware Requirements:** Currently runs on the Google Pixel 8 Pro, Pixel 9 series, and Samsung S24 series. It requires specialized NPUs (Neural Processing Units) like the Tensor G3/G4 or Snapdragon 8 Gen 3.
# *   **Capabilities:**
#     *   **Summarization:** Used in the Recorder app to summarize long recordings.
#     *   **Smart Reply:** Used in Gboard to suggest high-quality responses in apps like WhatsApp.
#     *   **Proofreading:** Grammar and style corrections.
# *   **Architecture:** It is a multimodal-capable model, but the on-device version is currently optimized primarily for text and language processing.
#
# ---
#
# ### 2. Banana (Banana.dev - The Infrastructure)
# **Banana** is not a model itself, but a popular **serverless GPU platform** used by developers to host and deploy models like Gemini-competitors (Llama 3, Whisper, etc.).
#
# *   **Purpose:** It allows developers to run "Nano" sized models (and larger) in the cloud without managing servers.
# *   **Specifications:**
#     *   **Cold Boot Times:** Optimized to start AI models in under 10 seconds.
#     *   **Hardware:** Uses high-end NVIDIA GPUs (A100s, H100s, T4s).
#     *   **Function:** It "packages" models into containers to be called via API.
#
# ---
#
# ### Why the name "Banana"?
# If you saw the name **"Banana"** associated with an AI model on a site like **Hugging Face**, it was likely a **fine-tuned** version of a small model (like Llama or Phi) created by an independent developer who used "Banana" as a codename.
#
# **If you are thinking of something else—such as a specific "fruit-themed" coding project or a cryptocurrency (Banano/Nano)—please let me know and I can get you those specific numbers!**
# quit

# %%
workflow.get_state(config)
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='which is the latest model release by openai', additional_kwargs={}, response_metadata={}, id='3df60536-706e-4d7b-80f0-4facc19b2b0c'), AIMessage(content=[{'type': 'text', 'text': 'The latest and most advanced model released by OpenAI is the **OpenAI o1** series, which was officially moved out of its "preview" phase in **December 2024**.\n\nHere is a breakdown of the most recent releases:\n\n### 1. OpenAI o1 (The Reasoning Model)\nReleased in full in early December 2024 (following a "preview" period that began in September), **o1** is OpenAI’s first model designed specifically for complex reasoning.\n*   **Key Feature:** It uses "chain-of-thought" processing, meaning it "thinks" before it speaks to solve complex problems in mathematics, coding, and science.\n*   **Performance:** It significantly outperforms GPT-4o in STEM-related tasks.\n*   **Versions:** Includes the full **o1** model and **o1-mini** (a faster, cheaper version optimized for coding).\n\n### 2. GPT-4o ("Omni")\nReleased in May 2024, this remains the primary "flagship" model for most users.\n*   **Key Feature:** It is natively multimodal, meaning it can process and generate text, audio, and images simultaneously in real-time.\n*   **Usage:** It powers the standard ChatGPT experience, Voice Mode, and vision capabilities.\n\n### 3. GPT-4o mini\nReleased in July 2024, this replaced GPT-3.5 Turbo.\n*   **Key Feature:** It is a small, highly efficient model designed to be fast and very inexpensive for developers while still being smarter than older large models.\n\n### 4. Recent Feature Updates (Late 2024)\nWhile not "new models" in the architectural sense, OpenAI has recently integrated major new capabilities into these models:\n*   **ChatGPT Search:** A web-search feature that allows the model to provide up-to-the-minute information with citations.\n*   **Canvas:** A new interface for working on writing and coding projects side-by-side with the AI.\n\n**Summary:** \n*   If you want the **smartest reasoning** for math or logic: Use **o1**.\n*   If you want the **best all-around** model for talking, vision, and speed: Use **GPT-4o**.', 'extras': {'signature': '...'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3-flash-preview', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--01a08678-4942-7292-a167-5322449f8dae-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 9, 'output_tokens': 911, 'total_tokens': 920, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 422}}), HumanMessage(content='which are the specifications of nano banana', additional_kwargs={}, response_metadata={}, id='abb90221-d163-4640-8361-6bb4318dc9b0'), AIMessage(content=[{'type': 'text', 'text': 'There is no AI model or product officially released by OpenAI (or other major AI labs) called "Nano Banana."\n\nIt is likely you are referring to one of the following three things, which are often confused or share those names:\n\n### 1. Banano (The Cryptocurrency)\nThe most common tech-related use of these terms is **Banano (BAN)**, which is a "meme" fork of the **Nano (XNO)** cryptocurrency.\n*   **Architecture:** Based on Directed Acyclic Graph (DAG) technology (Block-lattice).\n*   **Fees:** Zero (feeless transactions).\n*   **Speed:** Near-instant transactions.\n*   **Distribution:** Distributed through folding@home (contributing to medical research) and games rather than traditional mining.\n*   **Community:** Known for being a "potassium-rich" meme community focused on education about crypto.\n\n### 2. Mechanical Keyboard Switches ("Banana" Switches)\nIf you are into PC hardware, you might be looking for "Banana" tactile switches (like those from **Keychron** or **C3Equalz**).\n*   **Type:** Tactile.\n*   **Actuation Force:** Usually around 57g - 60g.\n*   **Feel:** They are known for a "two-stage" long spring that gives a very snap ...
